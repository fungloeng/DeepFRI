# %%
# 检查训练集中的文件是否存在
import os
npz_dir = 'cafa_npz_source/'
with open('cafa_deepfri/MF_train.txt', 'r') as f:
    proteins = [line.strip() for line in f]
missing = [p for p in proteins if not os.path.exists(f'{npz_dir}/{p}.npz')]
print(f'训练集: {len(proteins)} 个蛋白质')
print(f'缺失文件: {len(missing)} 个')
if missing:
    print('前10个缺失的文件:')
    for p in missing[:10]:
        print(f'  {p}.npz')
# Out:
# 训练集: 37552 个蛋白质
# 缺失文件: 0 个

# %%
 # 检查训练集中的文件是否存在
import os
npz_dir = 'cafa_npz_source/'
with open('cafa_deepfri/MF_valid.txt', 'r') as f:
    proteins = [line.strip() for line in f]
missing = [p for p in proteins if not os.path.exists(f'{npz_dir}/{p}.npz')]
print(f'训练集: {len(proteins)} 个蛋白质')
print(f'缺失文件: {len(missing)} 个')
if missing:
    print('前10个缺失的文件:')
    for p in missing[:10]:
        print(f'  {p}.npz')
# Out:
# 训练集: 2398 个蛋白质
# 缺失文件: 0 个

# %%
import numpy as np

# 加载 .npz 文件
data = np.load('cafa_npz_source/A0A023FBW4.npz')

# 查看文件中包含的所有数组名称
print("包含的数组名称：", data.files)

# 查看某个数组的内容（例如名为 'arr_0' 的数组）
print("数组内容：", data['C_alpha'])

# 查看数组的形状和数据类型
print("形状：", data['C_alpha'].shape)
print("数据类型：", data['C_alpha'].dtype)
# Out:
# 包含的数组名称： ['C_alpha', 'seqres']
# 数组内容： [[50.  5.  5. ... 50. 50. 50.]
#  [ 5. 50.  5. ... 50. 50. 50.]
#  [ 5.  5. 50. ... 50. 50. 50.]
#  ...
#  [50. 50. 50. ... 50.  5.  5.]
#  [50. 50. 50. ...  5. 50.  5.]
#  [50. 50. 50. ...  5.  5. 50.]]
# 形状： (97, 97)
# 数据类型： float32
