# %%
# 检查训练集中的文件是否存在
import os
npz_dir = 'npz_source/'
with open('galaxy_deepfri/MF_train.txt', 'r') as f:
    proteins = [line.strip() for line in f]
missing = [p for p in proteins if not os.path.exists(f'{npz_dir}/{p}.npz')]
print(f'训练集: {len(proteins)} 个蛋白质')
print(f'缺失文件: {len(missing)} 个')
if missing:
    print('前10个缺失的文件:')
    for p in missing[:10]:
        print(f'  {p}.npz')
# Out:
# 训练集: 16469 个蛋白质
# 缺失文件: 742 个
# 前10个缺失的文件:
#   AF-Q5T2L2-F1-model_v4.npz
#   AF-P0C7N8-F1-model_v4.npz
#   AF-Q9UHW5-F1-model_v4.npz
#   AF-Q9NUV9-F1-model_v4.npz
#   ENST00000355235.8.npz
#   AF-Q8IUS5-F1-model_v4.npz
#   AF-Q9UDX4-F1-model_v4.npz
#   AF-Q8WWP7-F1-model_v4.npz
#   AF-Q8NH42-F1-model_v4.npz
#   AF-Q16204-F1-model_v4.npz

# %%
 # 检查训练集中的文件是否存在
import os
npz_dir = 'npz_source/'
with open('galaxy_deepfri/MF_valid.txt', 'r') as f:
    proteins = [line.strip() for line in f]
missing = [p for p in proteins if not os.path.exists(f'{npz_dir}/{p}.npz')]
print(f'训练集: {len(proteins)} 个蛋白质')
print(f'缺失文件: {len(missing)} 个')
if missing:
    print('前10个缺失的文件:')
    for p in missing[:10]:
        print(f'  {p}.npz')
# Out:
# 训练集: 2059 个蛋白质
# 缺失文件: 95 个
# 前10个缺失的文件:
#   AF-Q86SE5-F1-model_v4.npz
#   AF-Q17RB8-F1-model_v4.npz
#   AF-Q6ZVW7-F1-model_v4.npz
#   AF-A5D8T8-F1-model_v4.npz
#   AF-Q9BQ75-F1-model_v4.npz
#   AF-Q9H628-F1-model_v4.npz
#   AF-O95073-F1-model_v4.npz
#   AF-Q8NH63-F1-model_v4.npz
#   AF-Q8NG94-F1-model_v4.npz
#   AF-P0C7M8-F1-model_v4.npz
