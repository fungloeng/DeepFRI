# %%
import numpy as np

# 从文件中加载.npz文件
data = np.load('1S3P-A.npz')

# 打印文件中的数组
print(f"data:\n{data}\n")

print(f"data.files:\n{data.files}\n")

C_alpha = data['C_alpha']
print(f"C_alpha:\n{C_alpha}\n")
# Out:
# data:
# ...
#
# data.files:
# ['C_alpha', 'C_beta', 'seqres']
#
# C_alpha:
# [[ 0.          3.78686309  5.40081215 ... 22.04758072 24.37477684
#   25.75246239]
#  [ 3.78686309  0.          3.82549047 ... 18.7215023  20.88490868
#   22.08077049]
#  [ 5.40081215  3.82549047  0.         ... 20.15785027 22.35639191
#   23.05529404]
#  ...
#  [22.04758072 18.7215023  20.15785027 ...  0.          3.80606961
#    6.64381933]
#  [24.37477684 20.88490868 22.35639191 ...  3.80606961  0.
#    3.79458165]
#  [25.75246239 22.08077049 23.05529404 ...  6.64381933  3.79458165
#    0.        ]]
